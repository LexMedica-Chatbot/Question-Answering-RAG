# %%
import networkx as nx
import matplotlib.pyplot as plt

# Load file .graphml
G = nx.read_graphml("data/kg_data_50_new_cont.graphml")

# Gambar grafik sederhana
plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_size=50, font_size=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 # Gambar grafik sederhana
#       8 plt.figure(figsize=(10, 10))
# ----> 9 nx.draw(G, with_labels=True, node_size=50, font_size=8)
#      10 plt.show()
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\drawing\nx_pylab.py:126, in draw(G, pos, ax, **kwds)
#     123 if "with_labels" not in kwds:
#     124     kwds["with_labels"] = "labels" in kwds
# --> 126 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127 ax.set_axis_off()
#     128 plt.draw_if_interactive()
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\drawing\nx_pylab.py:312, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     309 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     311 if pos is None:
# --> 312     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     314 draw_networkx_nodes(G, pos, **node_kwds)
#     315 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\utils\decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 22:4, in argmap_spring_layout_19(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\drawing\layout.py:486, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     484         nnodes, _ = A.shape
#     485         k = dom_size / np.sqrt(nnodes)
# --> 486     pos = _sparse_fruchterman_reingold(
#     487         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     488     )
#     489 except ValueError:
#     490     A = nx.to_numpy_array(G, weight=weight)
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\utils\decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 30:4, in argmap__sparse_fruchterman_reingold_27(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\networkx\drawing\layout.py:621, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     619 delta = (pos[i] - pos).T
#     620 # distance between points
# --> 621 distance = np.sqrt((delta**2).sum(axis=0))
#     622 # enforce minimum distance of 0.01
#     623 distance = np.where(distance < 0.01, 0.01, distance)
#
# File d:\Vs Code\Kuliah\Skripsi\TA-RAG\Question-Answering-RAG\qa-system\lib\site-packages\numpy\core\_methods.py:47, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#      49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#
# KeyboardInterrupt:
